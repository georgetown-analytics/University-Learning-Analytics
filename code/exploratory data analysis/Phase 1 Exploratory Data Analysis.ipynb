# %% [markdown]
# # Phase 1 Exploratory Data Analysis

# %%
import psycopg2
import pandas as pd
import pandas.io.sql as pd_sql
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import missingno as mn
import os
import yellowbrick 
import matplotlib
from matplotlib import cm
from collections import OrderedDict
#import pydotplus
#import graphviz 


from pandas.plotting import scatter_matrix

import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
# %pwd
# Out:
# '/Users/lisaschreiber/Desktop/University-Learning-Analytics/data'

# %% [markdown]
# ## Reading the Data

# %%
#7 CSV Files Saved Locally on Desktop
dfstudentinfo = pd.read_csv("studentInfo.csv")
dfstudentasses = pd.read_csv("studentAssessment.csv")
dfvle = pd.read_csv("vle.csv")
dfstudentvle = pd.read_csv("studentVle.csv")
dfstudentreg = pd.read_csv ("studentRegistration.csv")
dfcourses = pd.read_csv ("courses.csv")
dfasses = pd.read_csv ("assessments.csv")

# %%
#checking present working drive to properly set path to load data
# %pwd
# Out:
# '/Users/lisaschreiber/Desktop/University-Learning-Analytics/data'

# %% [markdown]
# ## Value Counts and Distribution

# %%
dfstudentinfo.head()
# Out:
#   code_module code_presentation  id_student gender                region  \
# 0         AAA             2013J       11391      M   East Anglian Region
# 1         AAA             2013J       28400      F              Scotland
# 2         AAA             2013J       30268      F  North Western Region
# 3         AAA             2013J       31604      F     South East Region
# 4         AAA             2013J       32885      F  West Midlands Region
#
#        highest_education imd_band age_band  num_of_prev_attempts  \
# 0       HE Qualification  90-100%     55<=                     0
# 1       HE Qualification   20-30%    35-55                     0
# 2  A Level or Equivalent   30-40%    35-55                     0
# 3  A Level or Equivalent   50-60%    35-55                     0
# 4     Lower Than A Level   50-60%     0-35                     0
#
#    studied_credits disability final_result
# 0              240          N         Pass
# 1               60          N         Pass
# 2               60          Y    Withdrawn
# 3               60          N         Pass
# 4               60          N         Pass

# %%
# check data type for each feature

dfstudentinfo.dtypes
# Out:
# code_module             object
# code_presentation       object
# id_student               int64
# gender                  object
# region                  object
# highest_education       object
# imd_band                object
# age_band                object
# num_of_prev_attempts     int64
# studied_credits          int64
# disability              object
# final_result            object
# dtype: object

# %%
dfstudentinfo.shape
# Out:
# (32593, 12)

# %%
#Total Number of Registered Students, note that some students had the ability to withdraw and retake modules.
dfstudentinfo['id_student'].count()
# Out:
# 32593

# %%
#Total Number of Students 
dfstudentinfo['id_student'].nunique()
# Out:
# 28785

# %%
#max number of previous attemps a student attempted a module
dfstudentinfo['num_of_prev_attempts'].max()
# Out:
# 6

# %%
#Gender Distribution
dfstudentinfo['gender'].value_counts().plot(kind='bar', title='Gender', colormap=('Accent'))
plt.grid(b=None)

# %%
#Gender Counts
dfstudentinfo['gender'].value_counts()
# Out:
# M    17875
# F    14718
# Name: gender, dtype: int64

# %%
#3164 students registered and disclosed they had a disablity
dfstudentinfo['disability'].value_counts()
# Out:
# N    29429
# Y     3164
# Name: disability, dtype: int64

# %%
#general descriptive statistics for studied credits - number of credits for the module the student is currently studying 
dfstudentinfo['studied_credits'].describe()
# Out:
# count    32593.000000
# mean        79.758691
# std         41.071900
# min         30.000000
# 25%         60.000000
# 50%         60.000000
# 75%        120.000000
# max        655.000000
# Name: studied_credits, dtype: float64

# %% [markdown]
# ## Demographic Data on Regions

# %%
#Total number of Regions
dfstudentinfo['region'].nunique()
# Out:
# 13

# %%
#data distribution of regions
presentation_counts = dfstudentinfo['region'].value_counts()
print (presentation_counts)

#created pie chart and histogram charts. Compare both visuals to see which is better at displaying the data.

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
presentation_counts.plot(kind='pie')
plt.title('Region')


plt.subplot(1,2,2)
presentation_counts.plot(kind='barh')
plt.xlabel('Region')
plt.ylabel('Frequency')
plt.title('Student ID Distribution')
plt.grid(b=None)

# adding spacing between the two plots
plt.subplots_adjust(wspace=0.4)
# Out:
# Scotland                3446
# East Anglian Region     3340
# London Region           3216
# South Region            3092
# North Western Region    2906
# West Midlands Region    2582
# South West Region       2436
# East Midlands Region    2365
# South East Region       2111
# Wales                   2086
# Yorkshire Region        2006
# North Region            1823
# Ireland                 1184
# Name: region, dtype: int64

# %%
#Plotting the stacked Final Result Distrubution of Registered Students per Region
dfstudentinfo.groupby(['region','final_result']).size().unstack().plot(kind='barh',stacked=True, colormap='Set2', figsize = (8,5))
plt.grid(b=None)
plt.legend(loc = (1.1, 0.7)) 
plt.ylabel("Regions")
plt.xlabel("Frequency/Number of Students")
plt.title("Final Result Distribution Per Region")
#plt.savefig("~rft.png")
# Out:
# Text(0.5, 1.0, 'Final Result Distribution Per Region')

# %%
#Reviewing Value Counts of the Final Result per Region for Registered Students
dfstudentinfo.groupby(['region', 'final_result'])['final_result'].count()
# Out:
# region                final_result
# East Anglian Region   Distinction      327
#                       Fail             698
#                       Pass            1309
#                       Withdrawn       1006
# East Midlands Region  Distinction      200
#                       Fail             462
#                       Pass             881
#                       Withdrawn        822
# Ireland               Distinction       98
#                       Fail             261
#                       Pass             552
#                       Withdrawn        273
# London Region         Distinction      263
#                       Fail             744
#                       Pass            1099
#                       Withdrawn       1110
# North Region          Distinction      230
#                       Fail             327
#                       Pass             691
#                       Withdrawn        575
# North Western Region  Distinction      213
#                       Fail             704
#                       Pass             955
#                       Withdrawn       1034
# Scotland              Distinction      328
#                       Fail             852
#                       Pass            1359
#                       Withdrawn        907
# South East Region     Distinction      244
#                       Fail             375
#                       Pass             843
#                       Withdrawn        649
# South Region          Distinction      333
#                       Fail             544
#                       Pass            1287
#                       Withdrawn        928
# South West Region     Distinction      264
#                       Fail             465
#                       Pass             949
#                       Withdrawn        758
# Wales                 Distinction      177
#                       Fail             620
#                       Pass             765
#                       Withdrawn        524
# West Midlands Region  Distinction      182
#                       Fail             551
#                       Pass             936
#                       Withdrawn        913
# Yorkshire Region      Distinction      165
#                       Fail             449
#                       Pass             735
#                       Withdrawn        657
# Name: final_result, dtype: int64

# %% [markdown]
# ## Highest Education Level on Entry
#
# The Highest Education feature column is the student's education level upon entry to the module presentation.

# %%
#The following is the stacked Highest Education Distribution chart per region.
dfstudentinfo.groupby(['region','highest_education']).size().unstack().plot(kind='bar',stacked=True, colormap = 'Accent', figsize =(8,5))
plt.grid(b=None)
plt.legend(loc = (1.1, 0.7)) 
plt.ylabel("Frequency/Number of Students")
plt.xlabel("Regions")
plt.title("Highest Education per Region")
plt.show()

# %% [markdown]
# ## Poverty Index Indicator IMD Band
#
# The IMD Band (Index of Multiple Deprivation Band) ranks different regions by decile. 0-10% being the most deprived and 90-100% being the least deprived.

# %%
#Viewing the distribution of IMD Band per Region 
dfstudentinfo.groupby(['region','imd_band',]).size().unstack().plot(kind='barh',stacked=True, colormap = 'Paired', figsize = (8,5))
plt.grid(b=None)
plt.legend(loc = (1.1, 0.3)) 
plt.ylabel("Number of Students")
plt.xlabel("Regions")
plt.title("Distribution of IMD Band per Region")
plt.show()

# %% [markdown]
# ## Code Modules
# The Code Module is grouped into 7 codes and have two domains, Social Science & STEM. AAA BBB & GGG fall under Social Science, while CCC, DDD, EEE, FFF are STEM modules.

# %%
#Final Result Distribution per Code Module

dfstudentinfo.groupby(['code_module','final_result']).size().unstack().plot(kind='barh',stacked=True,figsize = (8,5))
plt.grid(b=None)
plt.legend(loc = (1.025, 0.7)) 
plt.ylabel("Frequency/Number of Students")
plt.xlabel("Code Module")
plt.title("Final Result Distribution per Code Module")
#plt.savefig("~rft.png")
# Out:
# Text(0.5, 1.0, 'Final Result Distribution per Code Module')

# %%
#Gender Distribution per Code Module. 

dfstudentinfo.groupby(['code_module','gender']).size().unstack().plot(kind='bar',stacked=False, colormap='summer', figsize = (8,5))
plt.grid(b=None)
plt.ylabel("Frequency/Number of Students")
plt.xlabel("Code Module Type")
plt.title("Gender Distribution per Code Module")
plt.show()

# %%
#Gender Counts per Code Module
dfstudentinfo.groupby(['code_module', 'gender'])['gender'].count()
# Out:
# code_module  gender
# AAA          F          314
#              M          434
# BBB          F         6991
#              M          918
# CCC          F         1101
#              M         3333
# DDD          F         2518
#              M         3754
# EEE          F          337
#              M         2597
# FFF          F         1414
#              M         6348
# GGG          F         2043
#              M          491
# Name: gender, dtype: int64

# %%
#Total Registered Student Counts per Code Module
dfstudentinfo.groupby(['code_module',])['code_module'].count()
# Out:
# code_module
# AAA     748
# BBB    7909
# CCC    4434
# DDD    6272
# EEE    2934
# FFF    7762
# GGG    2534
# Name: code_module, dtype: int64

# %%
#check pass and fail ratio for students in diffent regions
dfstudentinfo.groupby(['region','imd_band',]).size().unstack().plot(kind='bar',stacked=True, colormap = 'Pastel1', figsize = (8,5))
plt.grid(b=None)
plt.legend(loc = (1.1, 0.3)) 
plt.ylabel("Number of Students")
plt.xlabel("Regions")
plt.title("Distribution of IMD Band per Region")
plt.show()

# %% [markdown]
# ## Examining Null Values
#
# MissingNo - Python package used to visualize missning elements in a dataset.

# %%
#examine missing values in dataset 
mn.matrix(dfstudentinfo)

# %%
#counts of missing values and all rows
mn.bar(dfstudentinfo)

# %% [markdown]
# ## Plotting Histograms for Dataset

# %%
dfstudentinfo.hist(figsize=(20,10)) # Histogram for all features
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x12a4a9940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1276a4da0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x127751748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126fed0f0>]],
#       dtype=object)

# %%
dfvle.hist(figsize=(20,10)) # Histogram for all features
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x127a60780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125fe25c0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x126dc9320>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125fec668>]],
#       dtype=object)

# %%
dfasses.hist(figsize=(20,10)) # Histogram for all features
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1260efa20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126c751d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x126ca6710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10b5c1208>]],
#       dtype=object)

# %% [markdown]
# # Final Result

# %%
#data distribution of regions
presentation_counts = dfstudentinfo['final_result'].value_counts()
print (presentation_counts)

#created pie chart and histogram charts. Compare both visuals to see which is better at displaying the data.

plt.figure(figsize=(15,5))
plt.subplot(1,2,1)
presentation_counts.plot(kind='pie')
plt.ylabel('')
plt.legend(loc = (.9, .75)) 
plt.title('Final Result')


plt.subplot(1,2,2)
presentation_counts.plot(kind='barh')
plt.xlabel('Final Result')
plt.ylabel('Frequency')
plt.title('Student ID Distribution')
plt.grid(b=None)


# adding spacing between the two plots
plt.subplots_adjust(wspace=0.4)
# Out:
# Pass           12361
# Withdrawn      10156
# Fail            7052
# Distinction     3024
# Name: final_result, dtype: int64

# %%
plt.subplot(1,2,2)
presentation_counts.plot(kind='barh', stacked=True)
plt.xlabel('Final Result')
plt.ylabel('Frequency')
plt.title('Student ID Distribution')
plt.grid(b=None)

# %%
#Final Result Distribution per Code Module

dfstudentinfo.groupby(['gender','final_result']).size().unstack().plot(kind='barh',stacked=True,figsize = (8,5))
plt.grid(b=None)
plt.legend(loc = (1.025, 0.7)) 
plt.ylabel("Frequency/Number of Students")
plt.xlabel("Gender")
plt.title("Final Result Distribution by Gender")
#plt.savefig("~rft.png")
# Out:
# Text(0.5, 1.0, 'Final Result Distribution by Gender')

# %%
dfstudentinfo.groupby(['region','final_result']).size().unstack().plot(kind='barh',stacked=True,figsize = (8,5))
plt.grid(b=None)
plt.legend(loc = (1.025, 0.7)) 
plt.ylabel("Frequency/Number of Students")
plt.xlabel("region")
plt.title("Final Result Distribution by Region")
# Out:
# Text(0.5, 1.0, 'Final Result Distribution by Region')

# %%
#Gender Distribution
dfstudentinfo['code_presentation'].value_counts().plot(kind='bar', title='Semester and Year', colormap=('Accent'))
plt.grid(b=None)

# %%
#Gender Distribution
dfstudentinfo['code_module'].value_counts().plot(kind='bar', title='Course Module', colormap=('Accent'))
plt.grid(b=None)
